# %%
import numpy as np
import caffe
caffe.set_mode_cpu()
# Out:
# /home/walle/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Net<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /home/walle/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Blob<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \
# /home/walle/caffe/python/caffe/pycaffe.py:13: RuntimeWarning: to-Python converter for boost::shared_ptr<caffe::Solver<float> > already registered; second conversion method ignored.
#   from ._caffe import Net, SGDSolver, NesterovSolver, AdaGradSolver, \

# %%
home = "/home/walle/"

MODEL_FILE = home + 'Attendance/extras/models/ResNet-101-deploy.prototxt'
PRETRAINED = home + 'Attendance/extras/models/ResNet-101-model.caffemodel'

net = caffe.Net(MODEL_FILE, PRETRAINED, caffe.TRAIN)

# %%
[(name, lr.blobs) for name, lr in zip(net._layer_names, net.layers) if len(lr.blobs) > 0]
# Out:
# [('conv1', <caffe._caffe.BlobVec at 0x5cd1600>),
#  ('bn_conv1', <caffe._caffe.BlobVec at 0x63426e0>),
#  ('scale_conv1', <caffe._caffe.BlobVec at 0x6d851a0>),
#  ('res2a_branch1', <caffe._caffe.BlobVec at 0x6d85de0>),
#  ('bn2a_branch1', <caffe._caffe.BlobVec at 0x6d85e50>),
#  ('scale2a_branch1', <caffe._caffe.BlobVec at 0x6d85ec0>),
#  ('res2a_branch2a', <caffe._caffe.BlobVec at 0x6d85f30>),
#  ('bn2a_branch2a', <caffe._caffe.BlobVec at 0x6d85fa0>),
#  ('scale2a_branch2a', <caffe._caffe.BlobVec at 0x6dd8050>),
#  ('res2a_branch2b', <caffe._caffe.BlobVec at 0x6dd80c0>),
#  ('bn2a_branch2b', <caffe._caffe.BlobVec at 0x6dd8130>),
#  ('scale2a_branch2b', <caffe._caffe.BlobVec at 0x6dd81a0>),
#  ('res2a_branch2c', <caffe._caffe.BlobVec at 0x6dd8210>),
#  ('bn2a_branch2c', <caffe._caffe.BlobVec at 0x6dd8280>),
#  ('scale2a_branch2c', <caffe._caffe.BlobVec at 0x6dd82f0>),
#  ('res2b_branch2a', <caffe._caffe.BlobVec at 0x6dd8360>),
#  ('bn2b_branch2a', <caffe._caffe.BlobVec at 0x6dd83d0>),
#  ('scale2b_branch2a', <caffe._caffe.BlobVec at 0x6dd8440>),
#  ('res2b_branch2b', <caffe._caffe.BlobVec at 0x6dd84b0>),
#  ('bn2b_branch2b', <caffe._caffe.BlobVec at 0x6dd8520>),
#  ('scale2b_branch2b', <caffe._caffe.BlobVec at 0x6dd8590>),
#  ('res2b_branch2c', <caffe._caffe.BlobVec at 0x6dd8600>),
#  ('bn2b_branch2c', <caffe._caffe.BlobVec at 0x6dd8670>),
#  ('scale2b_branch2c', <caffe._caffe.BlobVec at 0x6dd86e0>),
#  ('res2c_branch2a', <caffe._caffe.BlobVec at 0x6dd8750>),
#  ('bn2c_branch2a', <caffe._caffe.BlobVec at 0x6dd87c0>),
#  ('scale2c_branch2a', <caffe._caffe.BlobVec at 0x6dd8830>),
#  ('res2c_branch2b', <caffe._caffe.BlobVec at 0x6dd88a0>),
#  ('bn2c_branch2b', <caffe._caffe.BlobVec at 0x6dd8910>),
#  ('scale2c_branch2b', <caffe._caffe.BlobVec at 0x6dd8980>),
#  ('res2c_branch2c', <caffe._caffe.BlobVec at 0x6dd89f0>),
#  ('bn2c_branch2c', <caffe._caffe.BlobVec at 0x6dd8a60>),
#  ('scale2c_branch2c', <caffe._caffe.BlobVec at 0x6dd8ad0>),
#  ('res3a_branch1', <caffe._caffe.BlobVec at 0x6dd8b40>),
#  ('bn3a_branch1', <caffe._caffe.BlobVec at 0x6dd8bb0>),
#  ('scale3a_branch1', <caffe._caffe.BlobVec at 0x6dd8c20>),
#  ('res3a_branch2a', <caffe._caffe.BlobVec at 0x6dd8c90>),
#  ('bn3a_branch2a', <caffe._caffe.BlobVec at 0x6dd8d00>),
#  ('scale3a_branch2a', <caffe._caffe.BlobVec at 0x6dd8d70>),
#  ('res3a_branch2b', <caffe._caffe.BlobVec at 0x6dd8de0>),
#  ('bn3a_branch2b', <caffe._caffe.BlobVec at 0x6dd8e50>),
#  ('scale3a_branch2b', <caffe._caffe.BlobVec at 0x6dd8ec0>),
#  ('res3a_branch2c', <caffe._caffe.BlobVec at 0x6dd8f30>),
#  ('bn3a_branch2c', <caffe._caffe.BlobVec at 0x6dd8fa0>),
#  ('scale3a_branch2c', <caffe._caffe.BlobVec at 0x6dd9050>),
#  ('res3b1_branch2a', <caffe._caffe.BlobVec at 0x6dd90c0>),
#  ('bn3b1_branch2a', <caffe._caffe.BlobVec at 0x6dd9130>),
#  ('scale3b1_branch2a', <caffe._caffe.BlobVec at 0x6dd91a0>),
#  ('res3b1_branch2b', <caffe._caffe.BlobVec at 0x6dd9210>),
#  ('bn3b1_branch2b', <caffe._caffe.BlobVec at 0x6dd9280>),
#  ('scale3b1_branch2b', <caffe._caffe.BlobVec at 0x6dd92f0>),
#  ('res3b1_branch2c', <caffe._caffe.BlobVec at 0x6dd9360>),
#  ('bn3b1_branch2c', <caffe._caffe.BlobVec at 0x6dd93d0>),
#  ('scale3b1_branch2c', <caffe._caffe.BlobVec at 0x6dd9440>),
#  ('res3b2_branch2a', <caffe._caffe.BlobVec at 0x6dd94b0>),
#  ('bn3b2_branch2a', <caffe._caffe.BlobVec at 0x6dd9520>),
#  ('scale3b2_branch2a', <caffe._caffe.BlobVec at 0x6dd9590>),
#  ('res3b2_branch2b', <caffe._caffe.BlobVec at 0x6dd9600>),
#  ('bn3b2_branch2b', <caffe._caffe.BlobVec at 0x6dd9670>),
#  ('scale3b2_branch2b', <caffe._caffe.BlobVec at 0x6dd96e0>),
#  ('res3b2_branch2c', <caffe._caffe.BlobVec at 0x6dd9750>),
#  ('bn3b2_branch2c', <caffe._caffe.BlobVec at 0x6dd97c0>),
#  ('scale3b2_branch2c', <caffe._caffe.BlobVec at 0x6dd9830>),
#  ('res3b3_branch2a', <caffe._caffe.BlobVec at 0x6dd98a0>),
#  ('bn3b3_branch2a', <caffe._caffe.BlobVec at 0x6dd9910>),
#  ('scale3b3_branch2a', <caffe._caffe.BlobVec at 0x6dd9980>),
#  ('res3b3_branch2b', <caffe._caffe.BlobVec at 0x6dd99f0>),
#  ('bn3b3_branch2b', <caffe._caffe.BlobVec at 0x6dd9a60>),
#  ('scale3b3_branch2b', <caffe._caffe.BlobVec at 0x6dd9ad0>),
#  ('res3b3_branch2c', <caffe._caffe.BlobVec at 0x6dd9b40>),
#  ('bn3b3_branch2c', <caffe._caffe.BlobVec at 0x6dd9bb0>),
#  ('scale3b3_branch2c', <caffe._caffe.BlobVec at 0x6dd9c20>),
#  ('res4a_branch1', <caffe._caffe.BlobVec at 0x6dd9c90>),
#  ('bn4a_branch1', <caffe._caffe.BlobVec at 0x6dd9d00>),
#  ('scale4a_branch1', <caffe._caffe.BlobVec at 0x6dd9d70>),
#  ('res4a_branch2a', <caffe._caffe.BlobVec at 0x6dd9de0>),
#  ('bn4a_branch2a', <caffe._caffe.BlobVec at 0x6dd9e50>),
#  ('scale4a_branch2a', <caffe._caffe.BlobVec at 0x6dd9ec0>),
#  ('res4a_branch2b', <caffe._caffe.BlobVec at 0x6dd9f30>),
#  ('bn4a_branch2b', <caffe._caffe.BlobVec at 0x6dd9fa0>),
#  ('scale4a_branch2b', <caffe._caffe.BlobVec at 0x6ddd050>),
#  ('res4a_branch2c', <caffe._caffe.BlobVec at 0x6ddd0c0>),
#  ('bn4a_branch2c', <caffe._caffe.BlobVec at 0x6ddd130>),
#  ('scale4a_branch2c', <caffe._caffe.BlobVec at 0x6ddd1a0>),
#  ('res4b1_branch2a', <caffe._caffe.BlobVec at 0x6ddd210>),
#  ('bn4b1_branch2a', <caffe._caffe.BlobVec at 0x6ddd280>),
#  ('scale4b1_branch2a', <caffe._caffe.BlobVec at 0x6ddd2f0>),
#  ('res4b1_branch2b', <caffe._caffe.BlobVec at 0x6ddd360>),
#  ('bn4b1_branch2b', <caffe._caffe.BlobVec at 0x6ddd3d0>),
#  ('scale4b1_branch2b', <caffe._caffe.BlobVec at 0x6ddd440>),
#  ('res4b1_branch2c', <caffe._caffe.BlobVec at 0x6ddd4b0>),
#  ('bn4b1_branch2c', <caffe._caffe.BlobVec at 0x6ddd520>),
#  ('scale4b1_branch2c', <caffe._caffe.BlobVec at 0x6ddd590>),
#  ('res4b2_branch2a', <caffe._caffe.BlobVec at 0x6ddd600>),
#  ('bn4b2_branch2a', <caffe._caffe.BlobVec at 0x6ddd670>),
#  ('scale4b2_branch2a', <caffe._caffe.BlobVec at 0x6ddd6e0>),
#  ('res4b2_branch2b', <caffe._caffe.BlobVec at 0x6ddd750>),
#  ('bn4b2_branch2b', <caffe._caffe.BlobVec at 0x6ddd7c0>),
#  ('scale4b2_branch2b', <caffe._caffe.BlobVec at 0x6ddd830>),
#  ('res4b2_branch2c', <caffe._caffe.BlobVec at 0x6ddd8a0>),
#  ('bn4b2_branch2c', <caffe._caffe.BlobVec at 0x6ddd910>),
#  ('scale4b2_branch2c', <caffe._caffe.BlobVec at 0x6ddd980>),
#  ('res4b3_branch2a', <caffe._caffe.BlobVec at 0x6ddd9f0>),
#  ('bn4b3_branch2a', <caffe._caffe.BlobVec at 0x6ddda60>),
#  ('scale4b3_branch2a', <caffe._caffe.BlobVec at 0x6dddad0>),
#  ('res4b3_branch2b', <caffe._caffe.BlobVec at 0x6dddb40>),
#  ('bn4b3_branch2b', <caffe._caffe.BlobVec at 0x6dddbb0>),
#  ('scale4b3_branch2b', <caffe._caffe.BlobVec at 0x6dddc20>),
#  ('res4b3_branch2c', <caffe._caffe.BlobVec at 0x6dddc90>),
#  ('bn4b3_branch2c', <caffe._caffe.BlobVec at 0x6dddd00>),
#  ('scale4b3_branch2c', <caffe._caffe.BlobVec at 0x6dddd70>),
#  ('res4b4_branch2a', <caffe._caffe.BlobVec at 0x6dddde0>),
#  ('bn4b4_branch2a', <caffe._caffe.BlobVec at 0x6ddde50>),
#  ('scale4b4_branch2a', <caffe._caffe.BlobVec at 0x6dddec0>),
#  ('res4b4_branch2b', <caffe._caffe.BlobVec at 0x6dddf30>),
#  ('bn4b4_branch2b', <caffe._caffe.BlobVec at 0x6dddfa0>),
#  ('scale4b4_branch2b', <caffe._caffe.BlobVec at 0x6de3050>),
#  ('res4b4_branch2c', <caffe._caffe.BlobVec at 0x6de30c0>),
#  ('bn4b4_branch2c', <caffe._caffe.BlobVec at 0x6de3130>),
#  ('scale4b4_branch2c', <caffe._caffe.BlobVec at 0x6de31a0>),
#  ('res4b5_branch2a', <caffe._caffe.BlobVec at 0x6de3210>),
#  ('bn4b5_branch2a', <caffe._caffe.BlobVec at 0x6de3280>),
#  ('scale4b5_branch2a', <caffe._caffe.BlobVec at 0x6de32f0>),
#  ('res4b5_branch2b', <caffe._caffe.BlobVec at 0x6de3360>),
#  ('bn4b5_branch2b', <caffe._caffe.BlobVec at 0x6de33d0>),
#  ('scale4b5_branch2b', <caffe._caffe.BlobVec at 0x6de3440>),
#  ('res4b5_branch2c', <caffe._caffe.BlobVec at 0x6de34b0>),
#  ('bn4b5_branch2c', <caffe._caffe.BlobVec at 0x6de3520>),
#  ('scale4b5_branch2c', <caffe._caffe.BlobVec at 0x6de3590>),
#  ('res4b6_branch2a', <caffe._caffe.BlobVec at 0x6de3600>),
#  ('bn4b6_branch2a', <caffe._caffe.BlobVec at 0x6de3670>),
#  ('scale4b6_branch2a', <caffe._caffe.BlobVec at 0x6de36e0>),
#  ('res4b6_branch2b', <caffe._caffe.BlobVec at 0x6de3750>),
#  ('bn4b6_branch2b', <caffe._caffe.BlobVec at 0x6de37c0>),
#  ('scale4b6_branch2b', <caffe._caffe.BlobVec at 0x6de3830>),
#  ('res4b6_branch2c', <caffe._caffe.BlobVec at 0x6de38a0>),
#  ('bn4b6_branch2c', <caffe._caffe.BlobVec at 0x6de3910>),
#  ('scale4b6_branch2c', <caffe._caffe.BlobVec at 0x6de3980>),
#  ('res4b7_branch2a', <caffe._caffe.BlobVec at 0x6de39f0>),
#  ('bn4b7_branch2a', <caffe._caffe.BlobVec at 0x6de3a60>),
#  ('scale4b7_branch2a', <caffe._caffe.BlobVec at 0x6de3ad0>),
#  ('res4b7_branch2b', <caffe._caffe.BlobVec at 0x6de3b40>),
#  ('bn4b7_branch2b', <caffe._caffe.BlobVec at 0x6de3bb0>),
#  ('scale4b7_branch2b', <caffe._caffe.BlobVec at 0x6de3c20>),
#  ('res4b7_branch2c', <caffe._caffe.BlobVec at 0x6de3c90>),
#  ('bn4b7_branch2c', <caffe._caffe.BlobVec at 0x6de3d00>),
#  ('scale4b7_branch2c', <caffe._caffe.BlobVec at 0x6de3d70>),
#  ('res4b8_branch2a', <caffe._caffe.BlobVec at 0x6de3de0>),
#  ('bn4b8_branch2a', <caffe._caffe.BlobVec at 0x6de3e50>),
#  ('scale4b8_branch2a', <caffe._caffe.BlobVec at 0x6de3ec0>),
#  ('res4b8_branch2b', <caffe._caffe.BlobVec at 0x6de3f30>),
#  ('bn4b8_branch2b', <caffe._caffe.BlobVec at 0x6de3fa0>),
#  ('scale4b8_branch2b', <caffe._caffe.BlobVec at 0x6de5050>),
#  ('res4b8_branch2c', <caffe._caffe.BlobVec at 0x6de50c0>),
#  ('bn4b8_branch2c', <caffe._caffe.BlobVec at 0x6de5130>),
#  ('scale4b8_branch2c', <caffe._caffe.BlobVec at 0x6de51a0>),
#  ('res4b9_branch2a', <caffe._caffe.BlobVec at 0x6de5210>),
#  ('bn4b9_branch2a', <caffe._caffe.BlobVec at 0x6de5280>),
#  ('scale4b9_branch2a', <caffe._caffe.BlobVec at 0x6de52f0>),
#  ('res4b9_branch2b', <caffe._caffe.BlobVec at 0x6de5360>),
#  ('bn4b9_branch2b', <caffe._caffe.BlobVec at 0x6de53d0>),
#  ('scale4b9_branch2b', <caffe._caffe.BlobVec at 0x6de5440>),
#  ('res4b9_branch2c', <caffe._caffe.BlobVec at 0x6de54b0>),
#  ('bn4b9_branch2c', <caffe._caffe.BlobVec at 0x6de5520>),
#  ('scale4b9_branch2c', <caffe._caffe.BlobVec at 0x6de5590>),
#  ('res4b10_branch2a', <caffe._caffe.BlobVec at 0x6de5600>),
#  ('bn4b10_branch2a', <caffe._caffe.BlobVec at 0x6de5670>),
#  ('scale4b10_branch2a', <caffe._caffe.BlobVec at 0x6de56e0>),
#  ('res4b10_branch2b', <caffe._caffe.BlobVec at 0x6de5750>),
#  ('bn4b10_branch2b', <caffe._caffe.BlobVec at 0x6de57c0>),
#  ('scale4b10_branch2b', <caffe._caffe.BlobVec at 0x6de5830>),
#  ('res4b10_branch2c', <caffe._caffe.BlobVec at 0x6de58a0>),
#  ('bn4b10_branch2c', <caffe._caffe.BlobVec at 0x6de5910>),
#  ('scale4b10_branch2c', <caffe._caffe.BlobVec at 0x6de5980>),
#  ('res4b11_branch2a', <caffe._caffe.BlobVec at 0x6de59f0>),
#  ('bn4b11_branch2a', <caffe._caffe.BlobVec at 0x6de5a60>),
#  ('scale4b11_branch2a', <caffe._caffe.BlobVec at 0x6de5ad0>),
#  ('res4b11_branch2b', <caffe._caffe.BlobVec at 0x6de5b40>),
#  ('bn4b11_branch2b', <caffe._caffe.BlobVec at 0x6de5bb0>),
#  ('scale4b11_branch2b', <caffe._caffe.BlobVec at 0x6de5c20>),
#  ('res4b11_branch2c', <caffe._caffe.BlobVec at 0x6de5c90>),
#  ('bn4b11_branch2c', <caffe._caffe.BlobVec at 0x6de5d00>),
#  ('scale4b11_branch2c', <caffe._caffe.BlobVec at 0x6de5d70>),
#  ('res4b12_branch2a', <caffe._caffe.BlobVec at 0x6de5de0>),
#  ('bn4b12_branch2a', <caffe._caffe.BlobVec at 0x6de5e50>),
#  ('scale4b12_branch2a', <caffe._caffe.BlobVec at 0x6de5ec0>),
#  ('res4b12_branch2b', <caffe._caffe.BlobVec at 0x6de5f30>),
#  ('bn4b12_branch2b', <caffe._caffe.BlobVec at 0x6de5fa0>),
#  ('scale4b12_branch2b', <caffe._caffe.BlobVec at 0x6de9050>),
#  ('res4b12_branch2c', <caffe._caffe.BlobVec at 0x6de90c0>),
#  ('bn4b12_branch2c', <caffe._caffe.BlobVec at 0x6de9130>),
#  ('scale4b12_branch2c', <caffe._caffe.BlobVec at 0x6de91a0>),
#  ('res4b13_branch2a', <caffe._caffe.BlobVec at 0x6de9210>),
#  ('bn4b13_branch2a', <caffe._caffe.BlobVec at 0x6de9280>),
#  ('scale4b13_branch2a', <caffe._caffe.BlobVec at 0x6de92f0>),
#  ('res4b13_branch2b', <caffe._caffe.BlobVec at 0x6de9360>),
#  ('bn4b13_branch2b', <caffe._caffe.BlobVec at 0x6de93d0>),
#  ('scale4b13_branch2b', <caffe._caffe.BlobVec at 0x6de9440>),
#  ('res4b13_branch2c', <caffe._caffe.BlobVec at 0x6de94b0>),
#  ('bn4b13_branch2c', <caffe._caffe.BlobVec at 0x6de9520>),
#  ('scale4b13_branch2c', <caffe._caffe.BlobVec at 0x6de9590>),
#  ('res4b14_branch2a', <caffe._caffe.BlobVec at 0x6de9600>),
#  ('bn4b14_branch2a', <caffe._caffe.BlobVec at 0x6de9670>),
#  ('scale4b14_branch2a', <caffe._caffe.BlobVec at 0x6de96e0>),
#  ('res4b14_branch2b', <caffe._caffe.BlobVec at 0x6de9750>),
#  ('bn4b14_branch2b', <caffe._caffe.BlobVec at 0x6de97c0>),
#  ('scale4b14_branch2b', <caffe._caffe.BlobVec at 0x6de9830>),
#  ('res4b14_branch2c', <caffe._caffe.BlobVec at 0x6de98a0>),
#  ('bn4b14_branch2c', <caffe._caffe.BlobVec at 0x6de9910>),
#  ('scale4b14_branch2c', <caffe._caffe.BlobVec at 0x6de9980>),
#  ('res4b15_branch2a', <caffe._caffe.BlobVec at 0x6de99f0>),
#  ('bn4b15_branch2a', <caffe._caffe.BlobVec at 0x6de9a60>),
#  ('scale4b15_branch2a', <caffe._caffe.BlobVec at 0x6de9ad0>),
#  ('res4b15_branch2b', <caffe._caffe.BlobVec at 0x6de9b40>),
#  ('bn4b15_branch2b', <caffe._caffe.BlobVec at 0x6de9bb0>),
#  ('scale4b15_branch2b', <caffe._caffe.BlobVec at 0x6de9c20>),
#  ('res4b15_branch2c', <caffe._caffe.BlobVec at 0x6de9c90>),
#  ('bn4b15_branch2c', <caffe._caffe.BlobVec at 0x6de9d00>),
#  ('scale4b15_branch2c', <caffe._caffe.BlobVec at 0x6de9d70>),
#  ('res4b16_branch2a', <caffe._caffe.BlobVec at 0x6de9de0>),
#  ('bn4b16_branch2a', <caffe._caffe.BlobVec at 0x6de9e50>),
#  ('scale4b16_branch2a', <caffe._caffe.BlobVec at 0x6de9ec0>),
#  ('res4b16_branch2b', <caffe._caffe.BlobVec at 0x6de9f30>),
#  ('bn4b16_branch2b', <caffe._caffe.BlobVec at 0x6de9fa0>),
#  ('scale4b16_branch2b', <caffe._caffe.BlobVec at 0x6ded050>),
#  ('res4b16_branch2c', <caffe._caffe.BlobVec at 0x6ded0c0>),
#  ('bn4b16_branch2c', <caffe._caffe.BlobVec at 0x6ded130>),
#  ('scale4b16_branch2c', <caffe._caffe.BlobVec at 0x6ded1a0>),
#  ('res4b17_branch2a', <caffe._caffe.BlobVec at 0x6ded210>),
#  ('bn4b17_branch2a', <caffe._caffe.BlobVec at 0x6ded280>),
#  ('scale4b17_branch2a', <caffe._caffe.BlobVec at 0x6ded2f0>),
#  ('res4b17_branch2b', <caffe._caffe.BlobVec at 0x6ded360>),
#  ('bn4b17_branch2b', <caffe._caffe.BlobVec at 0x6ded3d0>),
#  ('scale4b17_branch2b', <caffe._caffe.BlobVec at 0x6ded440>),
#  ('res4b17_branch2c', <caffe._caffe.BlobVec at 0x6ded4b0>),
#  ('bn4b17_branch2c', <caffe._caffe.BlobVec at 0x6ded520>),
#  ('scale4b17_branch2c', <caffe._caffe.BlobVec at 0x6ded590>),
#  ('res4b18_branch2a', <caffe._caffe.BlobVec at 0x6ded600>),
#  ('bn4b18_branch2a', <caffe._caffe.BlobVec at 0x6ded670>),
#  ('scale4b18_branch2a', <caffe._caffe.BlobVec at 0x6ded6e0>),
#  ('res4b18_branch2b', <caffe._caffe.BlobVec at 0x6ded750>),
#  ('bn4b18_branch2b', <caffe._caffe.BlobVec at 0x6ded7c0>),
#  ('scale4b18_branch2b', <caffe._caffe.BlobVec at 0x6ded830>),
#  ('res4b18_branch2c', <caffe._caffe.BlobVec at 0x6ded8a0>),
#  ('bn4b18_branch2c', <caffe._caffe.BlobVec at 0x6ded910>),
#  ('scale4b18_branch2c', <caffe._caffe.BlobVec at 0x6ded980>),
#  ('res4b19_branch2a', <caffe._caffe.BlobVec at 0x6ded9f0>),
#  ('bn4b19_branch2a', <caffe._caffe.BlobVec at 0x6deda60>),
#  ('scale4b19_branch2a', <caffe._caffe.BlobVec at 0x6dedad0>),
#  ('res4b19_branch2b', <caffe._caffe.BlobVec at 0x6dedb40>),
#  ('bn4b19_branch2b', <caffe._caffe.BlobVec at 0x6dedbb0>),
#  ('scale4b19_branch2b', <caffe._caffe.BlobVec at 0x6dedc20>),
#  ('res4b19_branch2c', <caffe._caffe.BlobVec at 0x6dedc90>),
#  ('bn4b19_branch2c', <caffe._caffe.BlobVec at 0x6dedd00>),
#  ('scale4b19_branch2c', <caffe._caffe.BlobVec at 0x6dedd70>),
#  ('res4b20_branch2a', <caffe._caffe.BlobVec at 0x6dedde0>),
#  ('bn4b20_branch2a', <caffe._caffe.BlobVec at 0x6dede50>),
#  ('scale4b20_branch2a', <caffe._caffe.BlobVec at 0x6dedec0>),
#  ('res4b20_branch2b', <caffe._caffe.BlobVec at 0x6dedf30>),
#  ('bn4b20_branch2b', <caffe._caffe.BlobVec at 0x6dedfa0>),
#  ('scale4b20_branch2b', <caffe._caffe.BlobVec at 0x6df2050>),
#  ('res4b20_branch2c', <caffe._caffe.BlobVec at 0x6df20c0>),
#  ('bn4b20_branch2c', <caffe._caffe.BlobVec at 0x6df2130>),
#  ('scale4b20_branch2c', <caffe._caffe.BlobVec at 0x6df21a0>),
#  ('res4b21_branch2a', <caffe._caffe.BlobVec at 0x6df2210>),
#  ('bn4b21_branch2a', <caffe._caffe.BlobVec at 0x6df2280>),
#  ('scale4b21_branch2a', <caffe._caffe.BlobVec at 0x6df22f0>),
#  ('res4b21_branch2b', <caffe._caffe.BlobVec at 0x6df2360>),
#  ('bn4b21_branch2b', <caffe._caffe.BlobVec at 0x6df23d0>),
#  ('scale4b21_branch2b', <caffe._caffe.BlobVec at 0x6df2440>),
#  ('res4b21_branch2c', <caffe._caffe.BlobVec at 0x6df24b0>),
#  ('bn4b21_branch2c', <caffe._caffe.BlobVec at 0x6df2520>),
#  ('scale4b21_branch2c', <caffe._caffe.BlobVec at 0x6df2590>),
#  ('res4b22_branch2a', <caffe._caffe.BlobVec at 0x6df2600>),
#  ('bn4b22_branch2a', <caffe._caffe.BlobVec at 0x6df2670>),
#  ('scale4b22_branch2a', <caffe._caffe.BlobVec at 0x6df26e0>),
#  ('res4b22_branch2b', <caffe._caffe.BlobVec at 0x6df2750>),
#  ('bn4b22_branch2b', <caffe._caffe.BlobVec at 0x6df27c0>),
#  ('scale4b22_branch2b', <caffe._caffe.BlobVec at 0x6df2830>),
#  ('res4b22_branch2c', <caffe._caffe.BlobVec at 0x6df28a0>),
#  ('bn4b22_branch2c', <caffe._caffe.BlobVec at 0x6df2910>),
#  ('scale4b22_branch2c', <caffe._caffe.BlobVec at 0x6df2980>),
#  ('res5a_branch1', <caffe._caffe.BlobVec at 0x6df29f0>),
#  ('bn5a_branch1', <caffe._caffe.BlobVec at 0x6df2a60>),
#  ('scale5a_branch1', <caffe._caffe.BlobVec at 0x6df2ad0>),
#  ('res5a_branch2a', <caffe._caffe.BlobVec at 0x6df2b40>),
#  ('bn5a_branch2a', <caffe._caffe.BlobVec at 0x6df2bb0>),
#  ('scale5a_branch2a', <caffe._caffe.BlobVec at 0x6df2c20>),
#  ('res5a_branch2b', <caffe._caffe.BlobVec at 0x6df2c90>),
#  ('bn5a_branch2b', <caffe._caffe.BlobVec at 0x6df2d00>),
#  ('scale5a_branch2b', <caffe._caffe.BlobVec at 0x6df2d70>),
#  ('res5a_branch2c', <caffe._caffe.BlobVec at 0x6df2de0>),
#  ('bn5a_branch2c', <caffe._caffe.BlobVec at 0x6df2e50>),
#  ('scale5a_branch2c', <caffe._caffe.BlobVec at 0x6df2ec0>),
#  ('res5b_branch2a', <caffe._caffe.BlobVec at 0x6df2f30>),
#  ('bn5b_branch2a', <caffe._caffe.BlobVec at 0x6df2fa0>),
#  ('scale5b_branch2a', <caffe._caffe.BlobVec at 0x6df4050>),
#  ('res5b_branch2b', <caffe._caffe.BlobVec at 0x6df40c0>),
#  ('bn5b_branch2b', <caffe._caffe.BlobVec at 0x6df4130>),
#  ('scale5b_branch2b', <caffe._caffe.BlobVec at 0x6df41a0>),
#  ('res5b_branch2c', <caffe._caffe.BlobVec at 0x6df4210>),
#  ('bn5b_branch2c', <caffe._caffe.BlobVec at 0x6df4280>),
#  ('scale5b_branch2c', <caffe._caffe.BlobVec at 0x6df42f0>),
#  ('res5c_branch2a', <caffe._caffe.BlobVec at 0x6df4360>),
#  ('bn5c_branch2a', <caffe._caffe.BlobVec at 0x6df43d0>),
#  ('scale5c_branch2a', <caffe._caffe.BlobVec at 0x6df4440>),
#  ('res5c_branch2b', <caffe._caffe.BlobVec at 0x6df44b0>),
#  ('bn5c_branch2b', <caffe._caffe.BlobVec at 0x6df4520>),
#  ('scale5c_branch2b', <caffe._caffe.BlobVec at 0x6df4590>),
#  ('res5c_branch2c', <caffe._caffe.BlobVec at 0x6df4600>),
#  ('bn5c_branch2c', <caffe._caffe.BlobVec at 0x6df4670>),
#  ('scale5c_branch2c', <caffe._caffe.BlobVec at 0x6df46e0>),
#  ('fc1000', <caffe._caffe.BlobVec at 0x6df4750>)]

# %%
net.blobs['res2a_branch2c'].data
# Out:
# 0.0
